# %%
# %reset -f

# %%
user = "HHegde"
db = f"/Users/{user}/.data/oaklib/phenio.db"

# %%
# %reload_ext sql
# %sql sqlite:///{db}

# %%
# %sql SELECT * FROM term_association LIMIT 2;
# Out:
#  * sqlite:////Users/HHegde/.data/oaklib/phenio.db
# Done.
# [('uuid:70269c5a-42a9-11ee-be37-31ef105c25ea', 'MONDO:0023659', 'biolink:has_phenotype', 'HP:0011097', 'ECO:0000269', 'PMID:31675180', 'infores:hpo-annotations'),
#  ('uuid:70269c5b-42a9-11ee-be37-31ef105c25ea', 'MONDO:0023659', 'biolink:has_phenotype', 'HP:0002187', 'ECO:0000269', 'PMID:31675180', 'infores:hpo-annotations')]

# %%
import sqlite3
import pandas as pd
pd.set_option('display.max_rows', None)
from semsimian import Semsimian
from collections import Counter

# %%
conn = sqlite3.connect(db)
res = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
# tables = res.fetchall()

# tables

# %%
df_term_association = pd.read_sql_query("SELECT * FROM term_association", conn)
df_term_association.head()
# Out:
#                                           id        subject  \
# 0  uuid:70269c5a-42a9-11ee-be37-31ef105c25ea  MONDO:0023659
# 1  uuid:70269c5b-42a9-11ee-be37-31ef105c25ea  MONDO:0023659
# 2  uuid:70269c5c-42a9-11ee-be37-31ef105c25ea  MONDO:0023659
# 3  uuid:70269c5d-42a9-11ee-be37-31ef105c25ea  MONDO:0023659
# 4  uuid:70269c5e-42a9-11ee-be37-31ef105c25ea  MONDO:0023659
#
#                predicate      object evidence_type    publication  \
# 0  biolink:has_phenotype  HP:0011097   ECO:0000269  PMID:31675180
# 1  biolink:has_phenotype  HP:0002187   ECO:0000269  PMID:31675180
# 2  biolink:has_phenotype  HP:0001518   ECO:0000269  PMID:31675180
# 3  biolink:has_phenotype  HP:0032792   ECO:0000269  PMID:31675180
# 4  biolink:has_phenotype  HP:0011451   ECO:0000269  PMID:31675180
#
#                     source
# 0  infores:hpo-annotations
# 1  infores:hpo-annotations
# 2  infores:hpo-annotations
# 3  infores:hpo-annotations
# 4  infores:hpo-annotations

# %%
df_term_association['subject'].str.split(":").str[0].unique()
# Out:
# array(['MONDO', 'HGNC', 'WB', 'MGI', 'RGD', 'Xenbase', 'ZFIN'],
#       dtype=object)

# %%
df_term_association['object'].str.split(":").str[0].unique()
# Out:
# array(['HP', 'WBPhenotype', 'MP', 'XPO', 'ZP'], dtype=object)

# %%
df_100 = df_term_association[df_term_association['object'].str.startswith("HP:")].sample(n=50)#, random_state=1)
df_100 = df_100[['subject', 'predicate', 'object']]
df_100
# Out:
#               subject              predicate      object
# 141344  MONDO:0019129  biolink:has_phenotype  HP:0000718
# 212146  MONDO:0015234  biolink:has_phenotype  HP:0011800
# 20189   MONDO:0007363  biolink:has_phenotype  HP:0000248
# 953666     HGNC:23216  biolink:has_phenotype  HP:0001319
# 879352      HGNC:2309  biolink:has_phenotype  HP:0001028
# 874567     HGNC:14857  biolink:has_phenotype  HP:0011471
# 56067   MONDO:0100325  biolink:has_phenotype  HP:0000768
# 734035      HGNC:3806  biolink:has_phenotype  HP:0001561
# 694636       HGNC:868  biolink:has_phenotype  HP:0100702
# 182158  MONDO:0010680  biolink:has_phenotype  HP:0030117
# 800286      HGNC:9446  biolink:has_phenotype  HP:0010619
# 857676      HGNC:8768  biolink:has_phenotype  HP:0001252
# 698660      HGNC:1149  biolink:has_phenotype  HP:0001305
# 719012      HGNC:2953  biolink:has_phenotype  HP:0000007
# 211597  MONDO:0008426  biolink:has_phenotype  HP:0000316
# 958581     HGNC:19274  biolink:has_phenotype  HP:0000958
# 237010  MONDO:0016385  biolink:has_phenotype  HP:0000218
# 182205  MONDO:0008693  biolink:has_phenotype  HP:0000327
# 768614      HGNC:6893  biolink:has_phenotype  HP:0002145
# 181766  MONDO:0009024  biolink:has_phenotype  HP:0001162
# 808242     HGNC:10012  biolink:has_phenotype  HP:0000603
# 863261      HGNC:1738  biolink:has_phenotype  HP:0001137
# 117984  MONDO:0012172  biolink:has_phenotype  HP:0001518
# 949622     HGNC:25726  biolink:has_phenotype  HP:0001182
# 52950   MONDO:0030669  biolink:has_phenotype  HP:0000750
# 30561   MONDO:0024506  biolink:has_phenotype  HP:0001596
# 179562  MONDO:0009166  biolink:has_phenotype  HP:0004887
# 881987     HGNC:11465  biolink:has_phenotype  HP:0001643
# 826167     HGNC:11386  biolink:has_phenotype  HP:0001872
# 761610      HGNC:6407  biolink:has_phenotype  HP:0100763
# 949578     HGNC:28845  biolink:has_phenotype  HP:0000278
# 860350      HGNC:9479  biolink:has_phenotype  HP:0005280
# 152428  MONDO:0016988  biolink:has_phenotype  HP:0005979
# 712383      HGNC:2295  biolink:has_phenotype  HP:0000608
# 865351      HGNC:6912  biolink:has_phenotype  HP:0003202
# 90487   MONDO:0030859  biolink:has_phenotype  HP:0000657
# 83436   MONDO:0010404  biolink:has_phenotype  HP:0001319
# 213874  MONDO:0013226  biolink:has_phenotype  HP:0000411
# 69835   MONDO:0009661  biolink:has_phenotype  HP:0000268
# 835427     HGNC:12303  biolink:has_phenotype  HP:0000286
# 754306      HGNC:5439  biolink:has_phenotype  HP:0001974
# 225310  MONDO:0018106  biolink:has_phenotype  HP:0001370
# 80929   MONDO:0014465  biolink:has_phenotype  HP:0002099
# 830526     HGNC:11701  biolink:has_phenotype  HP:0011471
# 26434   MONDO:0013864  biolink:has_phenotype  HP:0001488
# 702648      HGNC:1653  biolink:has_phenotype  HP:0004332
# 153063  MONDO:0014475  biolink:has_phenotype  HP:0001260
# 905197     HGNC:13273  biolink:has_phenotype  HP:0002925
# 100150  MONDO:0034121  biolink:has_phenotype  HP:0008066
# 105094  MONDO:0013931  biolink:has_phenotype  HP:0000316

# %%
object_terms = set(df_100['object'])
object_terms
# Out:
# {'HP:0000007',
#  'HP:0000218',
#  'HP:0000248',
#  'HP:0000268',
#  'HP:0000278',
#  'HP:0000286',
#  'HP:0000316',
#  'HP:0000327',
#  'HP:0000411',
#  'HP:0000603',
#  'HP:0000608',
#  'HP:0000657',
#  'HP:0000718',
#  'HP:0000750',
#  'HP:0000768',
#  'HP:0000958',
#  'HP:0001028',
#  'HP:0001137',
#  'HP:0001162',
#  'HP:0001182',
#  'HP:0001252',
#  'HP:0001260',
#  'HP:0001305',
#  'HP:0001319',
#  'HP:0001370',
#  'HP:0001488',
#  'HP:0001518',
#  'HP:0001561',
#  'HP:0001596',
#  'HP:0001643',
#  'HP:0001872',
#  'HP:0001974',
#  'HP:0002099',
#  'HP:0002145',
#  'HP:0002925',
#  'HP:0003202',
#  'HP:0004332',
#  'HP:0004887',
#  'HP:0005280',
#  'HP:0005979',
#  'HP:0008066',
#  'HP:0010619',
#  'HP:0011471',
#  'HP:0011800',
#  'HP:0030117',
#  'HP:0100702',
#  'HP:0100763'}

# %%
# %%time

predicates= [
        "rdfs:subClassOf",
        "BFO:0000050",
        "UPHENO:0000001",
    ]
semsimian = Semsimian(
            spo=None,
            predicates=predicates,
            pairwise_similarity_attributes=None,
            resource_path=db,
        )
# Out:
# CPU times: user 18.5 s, sys: 1.03 s, total: 19.5 s
# Wall time: 19.6 s

# %%
def get_search_results(semsimian, object_terms, search_type):
    subject_prefixes = ["MONDO:"]
    assoc_predicate = {"biolink:has_phenotype"}
    limit = 100
    return semsimian.associations_search(
        assoc_predicate,
        object_terms,
        False,
        search_type,
        None,
        subject_prefixes,
        limit,
    )

def calculate_overlap(df, n):
    # Ensure n is not greater than the length of the dataframe
    n = min(n, len(df))
    
    # Slice the dataframe to only consider the first n rows
    df_sliced = df.iloc[:n]

    # Calculate the number of items in Full_search that also exist in Hybrid_search
    num_matches = sum(df_sliced["Full_search"].isin(df_sliced["Hybrid_search"]))
    
    
    # Calculate the percentage overlap
    percent_overlap = (num_matches / n) * 100
    
    return f"{percent_overlap}%"

# %%
# %%time

result_full  = get_search_results(semsimian, object_terms, "full")
# Out:
# CPU times: user 1h 32min 11s, sys: 42.6 s, total: 1h 32min 54s
# Wall time: 7min 5s

# %%
# %%time

result_hybrid  = get_search_results(semsimian, object_terms, "hybrid")
# Out:
# Using cache! "MONDO:biolink:has_phenotypefull"
# CPU times: user 22min 2s, sys: 11.2 s, total: 22min 13s
# Wall time: 2min 3s

# %%
result_full_curie_score = [[curie, score] for (score, _, curie) in result_full]
result_hybrid_curie_score = [[curie, score] for (score, _, curie) in result_hybrid]
len(result_full_curie_score) == len(result_hybrid_curie_score)
# Out:
# True

# %%
df_full = pd.DataFrame(result_full_curie_score, columns=["Full_search", "Full_score"])
df_hybrid = pd.DataFrame(result_hybrid_curie_score, columns=["Hybrid_search", "Hybrid_score"])
df = pd.concat([df_full, df_hybrid], axis=1)
df["MATCH"] = df["Full_search"] == df["Hybrid_search"]
df
# Out:
#       Full_search  Full_score  Hybrid_search  Hybrid_score  MATCH
# 0   MONDO:0033642   12.082923  MONDO:0033642     12.082923   True
# 1   MONDO:0800436   12.051874  MONDO:0800436     12.051874   True
# 2   MONDO:0859239   11.897094  MONDO:0859239     11.897094   True
# 3   MONDO:0859177   11.803907  MONDO:0859177     11.803907   True
# 4   MONDO:0032943   11.777875  MONDO:0032943     11.777875   True
# 5   MONDO:0014379   11.746804  MONDO:0014379     11.746804   True
# 6   MONDO:0013424   11.746580  MONDO:0013424     11.746580   True
# 7   MONDO:0014205   11.724396  MONDO:0014205     11.724396   True
# 8   MONDO:0033309   11.717613  MONDO:0033309     11.717613   True
# 9   MONDO:0014249   11.717285  MONDO:0014892     11.702170  False
# 10  MONDO:0014892   11.702170  MONDO:0012916     11.645791  False
# 11  MONDO:0012916   11.645791  MONDO:0012315     11.610028  False
# 12  MONDO:0013702   11.630768  MONDO:0007299     11.605633  False
# 13  MONDO:0012315   11.610028  MONDO:0014936     11.603686  False
# 14  MONDO:0007299   11.605633  MONDO:0009759     11.592116  False
# 15  MONDO:0014936   11.603686  MONDO:0012342     11.568032  False
# 16  MONDO:0009759   11.592116  MONDO:0007265     11.567042  False
# 17  MONDO:0012342   11.568032  MONDO:0025699     11.556940  False
# 18  MONDO:0007265   11.567042  MONDO:0012929     11.555772  False
# 19  MONDO:0025699   11.556940  MONDO:0011510     11.553398  False
# 20  MONDO:0012929   11.555772  MONDO:0014606     11.540744  False
# 21  MONDO:0011510   11.553398  MONDO:0020738     11.537014  False
# 22  MONDO:0008393   11.551029  MONDO:0013308     11.525225  False
# 23  MONDO:0014606   11.540744  MONDO:0859187     11.523596  False
# 24  MONDO:0020738   11.537014  MONDO:0859143     11.520654  False
# 25  MONDO:0013308   11.525225  MONDO:0010512     11.515692  False
# 26  MONDO:0859187   11.523596  MONDO:0011652     11.514177  False
# 27  MONDO:0859143   11.520654  MONDO:0012853     11.510890  False
# 28  MONDO:0010512   11.515692  MONDO:0032745     11.500178  False
# 29  MONDO:0011652   11.514177  MONDO:0009485     11.496460  False
# 30  MONDO:0012853   11.510890  MONDO:0032707     11.473373  False
# 31  MONDO:0032745   11.500178  MONDO:0009149     11.473183  False
# 32  MONDO:0009485   11.496460  MONDO:0013238     11.470813  False
# 33  MONDO:0032707   11.473373  MONDO:0800437     11.456249  False
# 34  MONDO:0009149   11.473183  MONDO:0010407     11.446536  False
# 35  MONDO:0013238   11.470813  MONDO:0013336     11.441825  False
# 36  MONDO:0859185   11.468921  MONDO:0060592     11.435982  False
# 37  MONDO:0800437   11.456249  MONDO:0013745     11.435426  False
# 38  MONDO:0014602   11.446852  MONDO:0859223     11.435258  False
# 39  MONDO:0010407   11.446536  MONDO:0054588     11.430278  False
# 40  MONDO:0013336   11.441825  MONDO:0013256     11.425568  False
# 41  MONDO:0060592   11.435982  MONDO:0012830     11.423991  False
# 42  MONDO:0013745   11.435426  MONDO:0014006     11.421821  False
# 43  MONDO:0859223   11.435258  MONDO:0010457     11.410182  False
# 44  MONDO:0054588   11.430278  MONDO:0010999     11.403632  False
# 45  MONDO:0013256   11.425568  MONDO:0859295     11.382838  False
# 46  MONDO:0012830   11.423991  MONDO:0025351     11.368339  False
# 47  MONDO:0014006   11.421821  MONDO:0010865     11.367091  False
# 48  MONDO:0010457   11.410182  MONDO:0011518     11.365824  False
# 49  MONDO:0010999   11.403632  MONDO:0013635     11.365070  False
# 50  MONDO:0859295   11.382838  MONDO:0013885     11.360248  False
# 51  MONDO:0025351   11.368339  MONDO:0014119     11.352522  False
# 52  MONDO:0010865   11.367091  MONDO:0008426     11.351488  False
# 53  MONDO:0011518   11.365824  MONDO:0032855     11.349084  False
# 54  MONDO:0013635   11.365070  MONDO:0009075     11.348333  False
# 55  MONDO:0011929   11.363481  MONDO:0008907     11.336445  False
# 56  MONDO:0013885   11.360248  MONDO:0009855     11.335979  False
# 57  MONDO:0014119   11.352522  MONDO:0030969     11.328019  False
# 58  MONDO:0008426   11.351488  MONDO:0030606     11.328007  False
# 59  MONDO:0032855   11.349084  MONDO:0008908     11.326352  False
# 60  MONDO:0009075   11.348333  MONDO:0011147     11.326246  False
# 61  MONDO:0008907   11.336445  MONDO:0011432     11.324250  False
# 62  MONDO:0009855   11.335979  MONDO:0013323     11.324091  False
# 63  MONDO:0030969   11.328019  MONDO:0013272     11.317512  False
# 64  MONDO:0030606   11.328007  MONDO:0010501     11.314460  False
# 65  MONDO:0008908   11.326352  MONDO:0018342     11.312206  False
# 66  MONDO:0011147   11.326246  MONDO:0010035     11.311414  False
# 67  MONDO:0011432   11.324250  MONDO:0009124     11.310556  False
# 68  MONDO:0013323   11.324091  MONDO:0014289     11.309637  False
# 69  MONDO:0013272   11.317512  MONDO:0014893     11.308757  False
# 70  MONDO:0009910   11.316299  MONDO:0014558     11.306636  False
# 71  MONDO:0010501   11.314460  MONDO:0014262     11.303979  False
# 72  MONDO:0018342   11.312206  MONDO:0030375     11.300165  False
# 73  MONDO:0010035   11.311414  MONDO:0007401     11.300060  False
# 74  MONDO:0009124   11.310556  MONDO:0018923     11.291670  False
# 75  MONDO:0014289   11.309637  MONDO:0010417     11.286571  False
# 76  MONDO:0014893   11.308757  MONDO:0032645     11.285382  False
# 77  MONDO:0014558   11.306636  MONDO:0013578     11.283994  False
# 78  MONDO:0014262   11.303979  MONDO:0044319     11.283269  False
# 79  MONDO:0030375   11.300165  MONDO:0020602     11.282830  False
# 80  MONDO:0007401   11.300060  MONDO:0010498     11.281399  False
# 81  MONDO:0013186   11.298613  MONDO:0009034     11.277968  False
# 82  MONDO:0018923   11.291670  MONDO:0010992     11.277694  False
# 83  MONDO:0010417   11.286571  MONDO:0015280     11.277082  False
# 84  MONDO:0032645   11.285382  MONDO:0014741     11.269992  False
# 85  MONDO:0014700   11.284869  MONDO:0033007     11.269867  False
# 86  MONDO:0013578   11.283994  MONDO:0010561     11.268283  False
# 87  MONDO:0044319   11.283269  MONDO:0859236     11.265949  False
# 88  MONDO:0032665   11.283268  MONDO:0054831     11.259254  False
# 89  MONDO:0020602   11.282830  MONDO:0033045     11.247646  False
# 90  MONDO:0010498   11.281399  MONDO:0859275     11.246958  False
# 91  MONDO:0009034   11.277968  MONDO:0859209     11.245948  False
# 92  MONDO:0010992   11.277694  MONDO:0032698     11.244112  False
# 93  MONDO:0015280   11.277082  MONDO:0008999     11.243329  False
# 94  MONDO:0014741   11.269992  MONDO:0018825     11.243018  False
# 95  MONDO:0033007   11.269867  MONDO:0033005     11.240376  False
# 96  MONDO:0010561   11.268283  MONDO:0012496     11.240322  False
# 97  MONDO:0010310   11.267964  MONDO:0018216     11.239753  False
# 98  MONDO:0859236   11.265949  MONDO:0018217     11.239753  False
# 99  MONDO:0054831   11.259254  MONDO:0010461     11.239027  False

# %%
# Extract the first element (MONDO ID) from each sublist in result_1 and result_2
search_result_1 = set([item[0] for item in result_full_curie_score])
search_result_2 = set([item[0] for item in result_hybrid_curie_score])

# Find the intersection of the two sets
common_results = search_result_1.intersection(search_result_2)

# Calculate the percentage of common terms
percentage_common = (len(common_results) / len(search_result_1)) * 100

print(f"Percentage of common terms: {percentage_common}%")
# Out:
# Percentage of common terms: 89.0%

# %%
calculate_overlap(df, 10)
# Out:
# '90.0%'
